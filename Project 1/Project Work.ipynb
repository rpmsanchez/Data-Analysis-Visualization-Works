# %%
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gmaps
from us import states

# %%
url = "http://public.gis.lacounty.gov/public/rest/services/LACounty_Dynamic/LMS_Data_Public/MapServer/146/query?where=1%3D1&outFields=OBJECTID,Name,addrln1,addrln2,city,Shape,post_id,description,zip,latitude,longitude&outSR=4326&f=json"
print(requests.get(url))
# Out:
# <Response [200]>

# %%
#print(requests.get(url).json())

response = requests.get(url).json()
# response1 = json.dumps(response, indent=4, sort_keys=True)
pprint(response)
# Out:
# {'displayFieldName': 'Name',
#  'features': [{'attributes': {'Name': 'City Of Los Angeles Police Department - '
#                                       'Headquarters',
#                               'OBJECTID': 140827787,
#                               'addrln1': '100 W. 1st St.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.052341,
#                               'longitude': -118.24403,
#                               'post_id': 59364,
#                               'zip': '90012'},
#                'geometry': {'x': -118.24403005635303, 'y': 34.0523409670783}},
#               {'attributes': {'Name': 'Los Angeles Police Department - North '
#                                       'Hollywood Community Police Station',
#                               'OBJECTID': 140827791,
#                               'addrln1': '11640 Burbank Blvd.',
#                               'addrln2': None,
#                               'city': 'North Hollywood',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.171986,
#                               'longitude': -118.385863,
#                               'post_id': 59368,
#                               'zip': '91601'},
#                'geometry': {'x': -118.38586305621008, 'y': 34.17198596700012}},
#               {'attributes': {'Name': 'Los Angeles Police Department - '
#                                       'Wilshire Community Police Station',
#                               'OBJECTID': 140827795,
#                               'addrln1': '4861 W. Venice Blvd.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.046571,
#                               'longitude': -118.34269,
#                               'post_id': 59372,
#                               'zip': '90019'},
#                'geometry': {'x': -118.34269005615927, 'y': 34.04657096640533}},
#               {'attributes': {'Name': 'Los Angeles Police Department - West '
#                                       'Los Angeles Community Police Station',
#                               'OBJECTID': 140827799,
#                               'addrln1': '1663 Butler Ave.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.043846,
#                               'longitude': -118.450697,
#                               'post_id': 59376,
#                               'zip': '90025'},
#                'geometry': {'x': -118.45069705565095, 'y': 34.04384596703088}},
#               {'attributes': {'Name': 'Los Angeles Police Department - Rampart '
#                                       'Community Police Station',
#                               'OBJECTID': 140827803,
#                               'addrln1': '1401 W. 6th St.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.056479,
#                               'longitude': -118.267458,
#                               'post_id': 59380,
#                               'zip': '90017'},
#                'geometry': {'x': -118.26745805596265, 'y': 34.05647896728497}},
#               {'attributes': {'Name': 'Los Angeles Police Department - Olympic '
#                                       'Community Police Station',
#                               'OBJECTID': 140827807,
#                               'addrln1': '1130 S. Vermont Ave.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.049817,
#                               'longitude': -118.291439,
#                               'post_id': 59384,
#                               'zip': '90006'},
#                'geometry': {'x': -118.29143905585572, 'y': 34.04981696692315}},
#               {'attributes': {'Name': 'City Of Claremont Police Department',
#                               'OBJECTID': 140827811,
#                               'addrln1': '570 W. Bonita Ave.',
#                               'addrln2': None,
#                               'city': 'Claremont',
#                               'description': 'The department provides law '
#                                              'enforcement for the city of '
#                                              'Claremont.',
#                               'latitude': 34.09639,
#                               'longitude': -117.722475,
#                               'post_id': 59388,
#                               'zip': '91711'},
#                'geometry': {'x': -117.72247505793285, 'y': 34.09638996750615}},
#               {'attributes': {'Name': 'City Of Whittier Police Department - '
#                                       'Police Services Center - Santa Fe '
#                                       'Springs',
#                               'OBJECTID': 140827815,
#                               'addrln1': '11576 Telegraph Rd.',
#                               'addrln2': None,
#                               'city': 'Santa Fe Springs',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'cities of Whittier and Santa Fe '
#                                              'Springs.',
#                               'latitude': 33.947024,
#                               'longitude': -118.086407,
#                               'post_id': 59392,
#                               'zip': '90670'},
#                'geometry': {'x': -118.08640705654784, 'y': 33.94702396718432}},
#               {'attributes': {'Name': 'City Of Culver City Police Department',
#                               'OBJECTID': 140827819,
#                               'addrln1': '4040 Duquesne Ave.',
#                               'addrln2': None,
#                               'city': 'Culver City',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Culver City.',
#                               'latitude': 34.020669,
#                               'longitude': -118.395097,
#                               'post_id': 59397,
#                               'zip': '90232'},
#                'geometry': {'x': -118.3950970564818, 'y': 34.020668966494}},
#               {'attributes': {'Name': 'City Of Montebello Police Department',
#                               'OBJECTID': 140827823,
#                               'addrln1': '1600 W. Beverly Blvd.',
#                               'addrln2': None,
#                               'city': 'Montebello',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Montebello.',
#                               'latitude': 34.020269,
#                               'longitude': -118.116431,
#                               'post_id': 59402,
#                               'zip': '90640'},
#                'geometry': {'x': -118.11643105707576, 'y': 34.02026896700537}},
#               {'attributes': {'Name': 'City Of Sierra Madre Police Department',
#                               'OBJECTID': 140827827,
#                               'addrln1': '242 W. Sierra Madre Blvd.',
#                               'addrln2': None,
#                               'city': 'Sierra Madre',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Sierra Madre.',
#                               'latitude': 34.161588,
#                               'longitude': -118.058441,
#                               'post_id': 59406,
#                               'zip': '91024'},
#                'geometry': {'x': -118.05844105656736, 'y': 34.16158796673933}},
#               {'attributes': {'Name': 'City Of Pasadena Police Department',
#                               'OBJECTID': 140827831,
#                               'addrln1': '207 N. Garfield Ave.',
#                               'addrln2': None,
#                               'city': 'Pasadena',
#                               'description': 'The department provides law '
#                                              'enforcement, mental health '
#                                              'services, and youth services for '
#                                              'the city of Pasadena.',
#                               'latitude': 34.149216,
#                               'longitude': -118.144849,
#                               'post_id': 59411,
#                               'zip': '91101'},
#                'geometry': {'x': -118.14484905700093, 'y': 34.14921596657051}},
#               {'attributes': {'Name': 'Malibu/Lost Hills Sheriff Station',
#                               'OBJECTID': 140831576,
#                               'addrln1': '27050 Agoura Rd.',
#                               'addrln2': None,
#                               'city': 'Calabasas',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.13735675,
#                               'longitude': -118.71418476,
#                               'post_id': 2347,
#                               'zip': '91301'},
#                'geometry': {'x': -118.71418481698613, 'y': 34.137356718134306}},
#               {'attributes': {'Name': 'East Los Angeles Sheriff Station',
#                               'OBJECTID': 140831580,
#                               'addrln1': '5019 E. 3Rd St.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.03411475,
#                               'longitude': -118.15772295,
#                               'post_id': 2243,
#                               'zip': '90022'},
#                'geometry': {'x': -118.15772300618163, 'y': 34.034114718321526}},
#               {'attributes': {'Name': 'Pico Rivera Sheriff Station',
#                               'OBJECTID': 140831584,
#                               'addrln1': '6631 S. Passons Blvd.',
#                               'addrln2': None,
#                               'city': 'Pico Rivera',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.9819147,
#                               'longitude': -118.0888921,
#                               'post_id': 2437,
#                               'zip': '90660'},
#                'geometry': {'x': -118.08889215881744, 'y': 33.98191467036964}},
#               {'attributes': {'Name': 'Cerritos Sheriff Station',
#                               'OBJECTID': 140831588,
#                               'addrln1': '18135 S. Bloomfield Ave.',
#                               'addrln2': None,
#                               'city': 'Cerritos',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.86633132,
#                               'longitude': -118.06592166,
#                               'post_id': 2221,
#                               'zip': '90703'},
#                'geometry': {'x': -118.06592172085848, 'y': 33.866331288614006}},
#               {'attributes': {'Name': 'Manhattan Beach Police Department',
#                               'OBJECTID': 140831607,
#                               'addrln1': '420 15th St',
#                               'addrln2': None,
#                               'city': 'Manhattan Beach',
#                               'description': 'The police department provides '
#                                              'law enforcement services for the '
#                                              'city of Manhattan Beach.',
#                               'latitude': 33.88695639,
#                               'longitude': -118.40928197,
#                               'post_id': 60213,
#                               'zip': '90266'},
#                'geometry': {'x': -118.4092820246009, 'y': 33.88695635750528}},
#               {'attributes': {'Name': 'Inglewood Police Department',
#                               'OBJECTID': 140774839,
#                               'addrln1': '1 Manchester Blvd.',
#                               'addrln2': None,
#                               'city': 'Inglewood',
#                               'description': 'The Agency Provides Law '
#                                              'Enforcement Services For The '
#                                              'City Of Inglewood.',
#                               'latitude': 33.96147649,
#                               'longitude': -118.3543253,
#                               'post_id': 4125,
#                               'zip': '90301'},
#                'geometry': {'x': -118.35432535640959, 'y': 33.96147645727962}},
#               {'attributes': {'Name': 'City Of Monrovia Police Department',
#                               'OBJECTID': 140827489,
#                               'addrln1': '140 E. Lime Ave.',
#                               'addrln2': None,
#                               'city': 'Monrovia',
#                               'description': 'The department provides drug '
#                                              'abuse services for youth and law '
#                                              'enforcement services for the '
#                                              'city of Monrovia.',
#                               'latitude': 34.147949,
#                               'longitude': -118.000061,
#                               'post_id': 59160,
#                               'zip': '91016'},
#                'geometry': {'x': -118.00006105687643, 'y': 34.14794896667951}},
#               {'attributes': {'Name': 'Los Angeles County Sheriff - San Dimas '
#                                       'Station',
#                               'OBJECTID': 140832426,
#                               'addrln1': '270 S Walnut Ave',
#                               'addrln2': None,
#                               'city': 'San Dimas',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.1047722,
#                               'longitude': -117.8016805,
#                               'post_id': 70425,
#                               'zip': '91773'},
#                'geometry': {'x': -117.80168055718258, 'y': 34.10477216735316}},
#               {'attributes': {'Name': 'City Of Burbank Police Department',
#                               'OBJECTID': 140832658,
#                               'addrln1': '200 N 3Rd St',
#                               'addrln2': None,
#                               'city': 'Burbank',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Burbank.',
#                               'latitude': 34.18285215,
#                               'longitude': -118.3084674,
#                               'post_id': 70634,
#                               'zip': '91502'},
#                'geometry': {'x': -118.30846745606782, 'y': 34.18285211649539}},
#               {'attributes': {'Name': 'City Of San Fernando Police Department',
#                               'OBJECTID': 140773879,
#                               'addrln1': '910 First St.',
#                               'addrln2': None,
#                               'city': 'San Fernando',
#                               'description': 'The department provides law '
#                                              'enforcement services and a '
#                                              'variety of crime prevention '
#                                              'programs for residents of the '
#                                              'city of San Fernando.',
#                               'latitude': 34.28278,
#                               'longitude': -118.438624,
#                               'post_id': 2253,
#                               'zip': '91340'},
#                'geometry': {'x': -118.43862405667521, 'y': 34.282779966116095}},
#               {'attributes': {'Name': 'City Of Covina Police Department',
#                               'OBJECTID': 140773904,
#                               'addrln1': '444 N. Citrus Ave.',
#                               'addrln2': None,
#                               'city': 'Covina',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Covina.',
#                               'latitude': 34.089779,
#                               'longitude': -117.889006,
#                               'post_id': 2392,
#                               'zip': '91723'},
#                'geometry': {'x': -117.88900605736126, 'y': 34.089778967239056}},
#               {'attributes': {'Name': 'Long Beach Police Department - North '
#                                       'Patrol Division',
#                               'OBJECTID': 140773925,
#                               'addrln1': '4891 Atlantic Ave.',
#                               'addrln2': None,
#                               'city': 'Long Beach',
#                               'description': 'The agency provides community '
#                                              'services, law enforcement and '
#                                              'mental health services for '
#                                              'people who live in the city of '
#                                              'Long Beach.',
#                               'latitude': 33.844639,
#                               'longitude': -118.185705,
#                               'post_id': 2464,
#                               'zip': '90807'},
#                'geometry': {'x': -118.18570505632808, 'y': 33.844638967678435}},
#               {'attributes': {'Name': 'Arcadia Police Department',
#                               'OBJECTID': 140831409,
#                               'addrln1': '250 W. Huntington Dr.',
#                               'addrln2': None,
#                               'city': 'Arcadia',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Arcadia.',
#                               'latitude': 34.13663745,
#                               'longitude': -118.03989351,
#                               'post_id': 59393,
#                               'zip': '91007'},
#                'geometry': {'x': -118.03989356527794, 'y': 34.13663742034998}},
#               {'attributes': {'Name': 'City Of West Covina Fire Department',
#                               'OBJECTID': 140833069,
#                               'addrln1': '1444 W Garvey Ave S',
#                               'addrln2': None,
#                               'city': 'West Covina',
#                               'description': 'The department provides fire and '
#                                              'rescue services for people of '
#                                              'all ages in West Covina.',
#                               'latitude': 34.07138257,
#                               'longitude': -117.9388456,
#                               'post_id': 70897,
#                               'zip': '91790'},
#                'geometry': {'x': -117.93884565744045, 'y': 34.071382537032456}},
#               {'attributes': {'Name': 'Los Angeles Police Department - Newton '
#                                       'Community Police Station',
#                               'OBJECTID': 140827788,
#                               'addrln1': '3400 S. Central Ave.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.012564,
#                               'longitude': -118.256302,
#                               'post_id': 59365,
#                               'zip': '90011'},
#                'geometry': {'x': -118.256302055932, 'y': 34.012563967190715}},
#               {'attributes': {'Name': 'Los Angeles Police Department - '
#                                       'Southwest Community Police Station',
#                               'OBJECTID': 140827792,
#                               'addrln1': '1546 W. Martin Luther King Jr. Blvd.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.010671,
#                               'longitude': -118.30503,
#                               'post_id': 59369,
#                               'zip': '90062'},
#                'geometry': {'x': -118.30503005665642, 'y': 34.01067096705847}},
#               {'attributes': {'Name': 'Los Angeles Police Department - '
#                                       'Southeast Community Police Station',
#                               'OBJECTID': 140827796,
#                               'addrln1': '145 W. 108th St.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 33.938438,
#                               'longitude': -118.275445,
#                               'post_id': 59373,
#                               'zip': '90061'},
#                'geometry': {'x': -118.27544505637994, 'y': 33.93843796690112}},
#               {'attributes': {'Name': 'Los Angeles Police Department - '
#                                       'Hollenbeck Community Police Station',
#                               'OBJECTID': 140827800,
#                               'addrln1': '2111 E. 1st. St.',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.044758,
#                               'longitude': -118.213091,
#                               'post_id': 59377,
#                               'zip': '90033'},
#                'geometry': {'x': -118.21309105610759, 'y': 34.044757966586054}},
#               {'attributes': {'Name': 'Los Angeles Police Department - 77Th '
#                                       'St. Community Police Station',
#                               'OBJECTID': 140827804,
#                               'addrln1': '7600 S. Broadway',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 33.970613,
#                               'longitude': -118.278035,
#                               'post_id': 59381,
#                               'zip': '90003'},
#                'geometry': {'x': -118.27803505601989, 'y': 33.97061296713064}},
#               {'attributes': {'Name': 'Los Angeles Police Department - Topanga '
#                                       'Community Police Station',
#                               'OBJECTID': 140827808,
#                               'addrln1': '21501 Schoenborn St.',
#                               'addrln2': None,
#                               'city': 'Canoga Park',
#                               'description': 'The department provides law '
#                                              'enforcement and youth services '
#                                              'for the City of Los Angeles.',
#                               'latitude': 34.221043,
#                               'longitude': -118.598916,
#                               'post_id': 59385,
#                               'zip': '91304'},
#                'geometry': {'x': -118.59891605589839, 'y': 34.22104296675079}},
#               {'attributes': {'Name': 'City Of La Verne Police Department',
#                               'OBJECTID': 140827812,
#                               'addrln1': '2061 Third St.',
#                               'addrln2': None,
#                               'city': 'La Verne',
#                               'description': 'The department provides law '
#                                              'enforcement for the City of La '
#                                              'Verne.',
#                               'latitude': 34.100824,
#                               'longitude': -117.770837,
#                               'post_id': 59389,
#                               'zip': '91750'},
#                'geometry': {'x': -117.77083705747268, 'y': 34.10082396696047}},
#               {'attributes': {'Name': 'City Of Azusa Police Department',
#                               'OBJECTID': 140827816,
#                               'addrln1': '725 N. Alameda Ave.',
#                               'addrln2': None,
#                               'city': 'Azusa',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Azusa.',
#                               'latitude': 34.134137,
#                               'longitude': -117.906387,
#                               'post_id': 59394,
#                               'zip': '91702'},
#                'geometry': {'x': -117.90638705686472, 'y': 34.134136966980996}},
#               {'attributes': {'Name': 'City Of El Monte Police Department',
#                               'OBJECTID': 140827820,
#                               'addrln1': '11333 E. Valley Blvd.',
#                               'addrln2': None,
#                               'city': 'El Monte',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of El Monte.',
#                               'latitude': 34.070934,
#                               'longitude': -118.030504,
#                               'post_id': 59398,
#                               'zip': '91731'},
#                'geometry': {'x': -118.03050405675968, 'y': 34.07093396720098}},
#               {'attributes': {'Name': 'City Of Pomona Police Department',
#                               'OBJECTID': 140827824,
#                               'addrln1': '490 W. Mission Blvd.',
#                               'addrln2': None,
#                               'city': 'Pomona',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Pomona.',
#                               'latitude': 34.054871,
#                               'longitude': -117.754267,
#                               'post_id': 59403,
#                               'zip': '91766'},
#                'geometry': {'x': -117.75426705753495, 'y': 34.054870967736065}},
#               {'attributes': {'Name': 'City Of South Pasadena Police '
#                                       'Department',
#                               'OBJECTID': 140827828,
#                               'addrln1': '1422 Mission St.',
#                               'addrln2': None,
#                               'city': 'South Pasadena',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of South Pasadena.',
#                               'latitude': 34.115955,
#                               'longitude': -118.152391,
#                               'post_id': 59408,
#                               'zip': '91030'},
#                'geometry': {'x': -118.15239105612629, 'y': 34.1159549664276}},
#               {'attributes': {'Name': 'Altadena Sheriff Station',
#                               'OBJECTID': 140831573,
#                               'addrln1': '780 E. Altadena Dr.',
#                               'addrln2': None,
#                               'city': 'Altadena',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.18957394,
#                               'longitude': -118.132478,
#                               'post_id': 2331,
#                               'zip': '91001'},
#                'geometry': {'x': -118.13247805546605, 'y': 34.18957390886317}},
#               {'attributes': {'Name': 'Carson Sheriff Station',
#                               'OBJECTID': 140831577,
#                               'addrln1': '21356 S. Avalon Blvd.',
#                               'addrln2': None,
#                               'city': 'Carson',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.83449494,
#                               'longitude': -118.26301038,
#                               'post_id': 2263,
#                               'zip': '90745'},
#                'geometry': {'x': -118.26301043948479, 'y': 33.834494903236376}},
#               {'attributes': {'Name': 'Industry Sheriff Station',
#                               'OBJECTID': 140831581,
#                               'addrln1': '150 N. Hudson Ave.',
#                               'addrln2': None,
#                               'city': 'Industry',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.02497045,
#                               'longitude': -117.95877278,
#                               'post_id': 2405,
#                               'zip': '91744'},
#                'geometry': {'x': -117.95877283630962, 'y': 34.02497041432325}},
#               {'attributes': {'Name': 'Norwalk Sheriff Station',
#                               'OBJECTID': 140831585,
#                               'addrln1': '12335 Civic Center Dr.',
#                               'addrln2': None,
#                               'city': 'Norwalk',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.91422419,
#                               'longitude': -118.06938171,
#                               'post_id': 2369,
#                               'zip': '90650'},
#                'geometry': {'x': -118.06938177014781, 'y': 33.91422415543039}},
#               {'attributes': {'Name': 'Compton Sheriff Station',
#                               'OBJECTID': 140831589,
#                               'addrln1': '301 S. Willowbrook Ave.',
#                               'addrln2': None,
#                               'city': 'Compton',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.8940816,
#                               'longitude': -118.2244429,
#                               'post_id': 2275,
#                               'zip': '90220'},
#                'geometry': {'x': -118.22444295507343, 'y': 33.894081569859964}},
#               {'attributes': {'Name': 'Burbank Police Department',
#                               'OBJECTID': 140774961,
#                               'addrln1': '200 N. Third St.',
#                               'addrln2': None,
#                               'city': 'Burbank',
#                               'description': 'The Department Provides Law '
#                                              'Enforcement Services For The '
#                                              'City Of Burbank.',
#                               'latitude': 34.18289863,
#                               'longitude': -118.3089144,
#                               'post_id': 4281,
#                               'zip': '91502'},
#                'geometry': {'x': -118.30891445644896, 'y': 34.18289859654194}},
#               {'attributes': {'Name': 'Universal Citywalk Substation',
#                               'OBJECTID': 140831213,
#                               'addrln1': '1000 Universal Studios Blvd., Bldg. '
#                                          '4505M',
#                               'addrln2': None,
#                               'city': 'Universal City',
#                               'description': 'Universal City is a one square '
#                                              'mile island of unincorporated '
#                                              'Los Angeles County, surrounded '
#                                              'by the City of Los Angeles. It '
#                                              'contains an entertainment theme '
#                                              'park (Universal '
#                                              'Studios-Hollywood), a complete '
#                                              'motion picture and television '
#                                              'production studio complex, a six '
#                                              'thousand five hundred seat '
#                                              'Amphitheater (Universal '
#                                              'Amphitheater), an eighteen '
#                                              'screen cinema (Universal Studios '
#                                              'Cinemas), and a large restaurant '
#                                              'and shopping district theme mall '
#                                              '(CityWalk). The average daily '
#                                              'population is approximately '
#                                              'fifty thousand. The Los Angeles '
#                                              "County Sheriff's Department "
#                                              'provides law enforcement '
#                                              'services to Universal City from '
#                                              'a Sub-Station located within the '
#                                              'CityWalk Theme Mall.\r\n'
#                                              '\r\n'
#                                              'Staffing for the substation '
#                                              'consists of 1-Lieutenant, '
#                                              '2-Sergeants, 1-Detective, 1-Team '
#                                              'leader, 12 Deputies and is '
#                                              'manned 24 hours a day by Deputy '
#                                              'and Security personnel.',
#                               'latitude': 34.1356428,
#                               'longitude': -118.3511309,
#                               'post_id': 67672,
#                               'zip': '91608'},
#                'geometry': {'x': -118.35113095603205, 'y': 34.13564276681248}},
#               {'attributes': {'Name': 'Los Angeles County Sheriff - Metro '
#                                       'Transit Services Bureau',
#                               'OBJECTID': 140832430,
#                               'addrln1': '1 Gateway Plaza Dr',
#                               'addrln2': None,
#                               'city': 'Los Angeles',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.05497141,
#                               'longitude': -118.2334602,
#                               'post_id': 70426,
#                               'zip': '90012'},
#                'geometry': {'x': -118.23346025651531, 'y': 34.05497137732923}},
#               {'attributes': {'Name': 'City Of Huntington Park Police '
#                                       'Department',
#                               'OBJECTID': 140826036,
#                               'addrln1': '6542 Miles Ave.',
#                               'addrln2': None,
#                               'city': 'Huntington Park',
#                               'description': 'The agency provides law '
#                                              'enforcement services for the '
#                                              'city of Huntington Park.',
#                               'latitude': 33.979963,
#                               'longitude': -118.218923,
#                               'post_id': 57843,
#                               'zip': '90255'},
#                'geometry': {'x': -118.21892305633354, 'y': 33.979962967056096}},
#               {'attributes': {'Name': 'West Hollywood Sheriff Station',
#                               'OBJECTID': 140836988,
#                               'addrln1': '780 No. San Vicente Blvd.',
#                               'addrln2': None,
#                               'city': 'West Hollywood',
#                               'description': 'West Hollywood Station provides '
#                                              'law enforcement services for the '
#                                              'City of West Hollywood and the '
#                                              'unincorporated Universal City '
#                                              'Walk. The City is approximately '
#                                              '1.9 square miles in size and has '
#                                              'a diverse demographic makeup. '
#                                              'The total residential population '
#                                              'is just over 37,000, however, '
#                                              'the nighttime and weekend '
#                                              'population swells to between '
#                                              '80,000 and 100,000, with a high '
#                                              'of up to 500,000 during major '
#                                              'events such as Halloween or the '
#                                              'Gay &amp; Lesbian Pride Parade.',
#                               'latitude': 34.083757,
#                               'longitude': -118.383608,
#                               'post_id': 67665,
#                               'zip': '90069'},
# ...
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.85140586,
#                               'longitude': -118.13317694,
#                               'post_id': 2259,
#                               'zip': '90712'},
#                'geometry': {'x': -118.13317699257539, 'y': 33.851405821943025}},
#               {'attributes': {'Name': 'Santa Clarita Valley Sheriff Station',
#                               'OBJECTID': 140831586,
#                               'addrln1': '23740 W. Magic Mountain Pkwy.',
#                               'addrln2': None,
#                               'city': 'Valencia',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 34.41574326,
#                               'longitude': -118.55134249,
#                               'post_id': 2415,
#                               'zip': '91355'},
#                'geometry': {'x': -118.55134254338876, 'y': 34.41574322935963}},
#               {'attributes': {'Name': 'Marina Del Rey Sheriff Station',
#                               'OBJECTID': 140831590,
#                               'addrln1': '13851 Fiji Way',
#                               'addrln2': None,
#                               'city': 'Marina Del Rey',
#                               'description': 'The department provides '
#                                              'correctional programs, disaster '
#                                              'services, environmental '
#                                              'services, holiday assistance, '
#                                              'law enforcement services, '
#                                              'substance abuse services and '
#                                              'youth services for the '
#                                              'unincorporated areas of Los '
#                                              'Angeles County and contracting '
#                                              'cities.',
#                               'latitude': 33.96954129,
#                               'longitude': -118.44572783,
#                               'post_id': 2342,
#                               'zip': '90292'},
#                'geometry': {'x': -118.44572788035187, 'y': 33.96954125859949}},
#               {'attributes': {'Name': 'Redondo Beach Police Department - Pier '
#                                       'Sub Station',
#                               'OBJECTID': 140774045,
#                               'addrln1': '133 W. Torrance Blvd.',
#                               'addrln2': None,
#                               'city': 'Redondo Beach',
#                               'description': 'The police department provides '
#                                              'law enforcement services for '
#                                              'residents of Redondo Beach.',
#                               'latitude': 33.838363,
#                               'longitude': -118.387567,
#                               'post_id': 2641,
#                               'zip': '90277'},
#                'geometry': {'x': -118.38756705563277, 'y': 33.83836296721554}},
#               {'attributes': {'Name': 'Downey Police Department',
#                               'OBJECTID': 140774962,
#                               'addrln1': '10911 Brookshire Ave.',
#                               'addrln2': None,
#                               'city': 'Downey',
#                               'description': 'The Department Provides Law '
#                                              'Enforcement Services For The '
#                                              'City Of Downey.',
#                               'latitude': 33.94136274,
#                               'longitude': -118.1266632,
#                               'post_id': 4282,
#                               'zip': '90241'},
#                'geometry': {'x': -118.12666325685957, 'y': 33.94136270733053}},
#               {'attributes': {'Name': 'San Dimas Sheriff Station',
#                               'OBJECTID': 140831869,
#                               'addrln1': '270 So. Walnut Ave. ',
#                               'addrln2': None,
#                               'city': 'San Dimas ',
#                               'description': "San Dimas\xa0Sheriff's Station "
#                                              'is located in\xa0the eastern '
#                                              'portion of Los Angeles County, '
#                                              'adjacent to the cities of La '
#                                              'Verne and Pomona. The station '
#                                              'serves the City of San Dimas\xa0'
#                                              'and the unincorporated '
#                                              'communities of Covina, Azusa , '
#                                              'Glendora, La Verne, and '
#                                              'Claremont. The station also '
#                                              'provides law enforcement for the '
#                                              'Azusa Canyon and Mount Baldy '
#                                              'areas of the Angeles National '
#                                              'Forest (State Route 39).',
#                               'latitude': 34.1047719,
#                               'longitude': -117.80168,
#                               'post_id': 67676,
#                               'zip': '91773-2646'},
#                'geometry': {'x': -117.80168005718814, 'y': 34.104771867224265}},
#               {'attributes': {'Name': 'City Of Downey Police Department',
#                               'OBJECTID': 140833287,
#                               'addrln1': '10911 Brookshire Ave',
#                               'addrln2': None,
#                               'city': 'Downey',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Downey.',
#                               'latitude': 33.94091482,
#                               'longitude': -118.127655,
#                               'post_id': 71048,
#                               'zip': '90241'},
#                'geometry': {'x': -118.12765505687541, 'y': 33.94091478732302}},
#               {'attributes': {'Name': 'City Of South Gate Police Department',
#                               'OBJECTID': 140827986,
#                               'addrln1': '8620 California Ave.',
#                               'addrln2': None,
#                               'city': 'South Gate',
#                               'description': 'The department provides safety '
#                                              'programs and law enforcement '
#                                              'services for the city of South '
#                                              'Gate.',
#                               'latitude': 33.955691,
#                               'longitude': -118.205232,
#                               'post_id': 59670,
#                               'zip': '90280'},
#                'geometry': {'x': -118.20523205581914, 'y': 33.95569096754303}},
#               {'attributes': {'Name': 'Walnut/Diamond Bar Sheriff Station',
#                               'OBJECTID': 140836989,
#                               'addrln1': '21695 Valley Blvd.',
#                               'addrln2': None,
#                               'city': 'Walnut',
#                               'description': 'Walnut/Diamond Bar Station is '
#                                              'spread out over 45.2 miles, '
#                                              'encompassing the contract cities '
#                                              'of Diamond Bar and Walnut, and '
#                                              'the unincorporated area of '
#                                              'Rowland Heights. We provide '
#                                              'police services, including all '
#                                              'patrol, investigative and '
#                                              'custodial operations, to more '
#                                              'than 148,000 residents.',
#                               'latitude': 34.02885584,
#                               'longitude': -117.83431189,
#                               'post_id': 67682,
#                               'zip': '91789'},
#                'geometry': {'x': -117.83431194690316, 'y': 34.028855803023646}},
#               {'attributes': {'Name': 'City Of Long Beach Police Department',
#                               'OBJECTID': 140773881,
#                               'addrln1': '400 W. Broadway',
#                               'addrln2': None,
#                               'city': 'Long Beach',
#                               'description': 'The agency provides community '
#                                              'services, law enforcement and '
#                                              'mental health services for '
#                                              'people who live in the city of '
#                                              'Long Beach.',
#                               'latitude': 33.768986,
#                               'longitude': -118.197253,
#                               'post_id': 2266,
#                               'zip': '90802'},
#                'geometry': {'x': -118.19725305575287, 'y': 33.76898596779304}},
#               {'attributes': {'Name': 'City Of Gardena Police Department',
#                               'OBJECTID': 140773913,
#                               'addrln1': '1718 W 162Nd St',
#                               'addrln2': None,
#                               'city': 'Gardena',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Gardena.',
#                               'latitude': 33.88372657,
#                               'longitude': -118.3076375,
#                               'post_id': 2440,
#                               'zip': '90247'},
#                'geometry': {'x': -118.30763755583416, 'y': 33.88372653692689}},
#               {'attributes': {'Name': 'Long Beach Police Department - East '
#                                       'Patrol Division',
#                               'OBJECTID': 140773927,
#                               'addrln1': '4800 Los Coyotes Diagonal',
#                               'addrln2': None,
#                               'city': 'Long Beach',
#                               'description': 'The agency provides community '
#                                              'services, law enforcement and '
#                                              'mental health services for '
#                                              'people who live in the city of '
#                                              'Long Beach.',
#                               'latitude': 33.792865,
#                               'longitude': -118.13782,
#                               'post_id': 2466,
#                               'zip': '90815'},
#                'geometry': {'x': -118.13782005608985, 'y': 33.79286496771328}},
#               {'attributes': {'Name': 'City Of Bell Police Department',
#                               'OBJECTID': 140832179,
#                               'addrln1': '6326 Pine Ave',
#                               'addrln2': None,
#                               'city': 'Bell',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Bell.',
#                               'latitude': 33.97952013,
#                               'longitude': -118.1887928,
#                               'post_id': 70258,
#                               'zip': '90201'},
#                'geometry': {'x': -118.18879285600518, 'y': 33.97952009733686}},
#               {'attributes': {'Name': 'City Of Signal Hill Police Department',
#                               'OBJECTID': 140840803,
#                               'addrln1': '2745 Walnut Ave',
#                               'addrln2': None,
#                               'city': 'Signal Hill',
#                               'description': 'The department provides law '
#                                              'enforcement services for the '
#                                              'city of Signal Hill.',
#                               'latitude': 33.8068604,
#                               'longitude': -118.1724497,
#                               'post_id': 59407,
#                               'zip': '90755'},
#                'geometry': {'x': -118.1724497565763, 'y': 33.80686036717903}}],
#  'fieldAliases': {'Name': 'Name',
#                   'OBJECTID': 'OBJECTID',
#                   'addrln1': 'addrln1',
#                   'addrln2': 'addrln2',
#                   'city': 'city',
#                   'description': 'description',
#                   'latitude': 'latitude',
#                   'longitude': 'longitude',
#                   'post_id': 'post_id',
#                   'zip': 'zip'},
#  'fields': [{'alias': 'OBJECTID',
#              'name': 'OBJECTID',
#              'type': 'esriFieldTypeOID'},
#             {'alias': 'Name',
#              'length': 150,
#              'name': 'Name',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'addrln1',
#              'length': 75,
#              'name': 'addrln1',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'addrln2',
#              'length': 75,
#              'name': 'addrln2',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'city',
#              'length': 35,
#              'name': 'city',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'post_id',
#              'name': 'post_id',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'description',
#              'length': 4000,
#              'name': 'description',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'zip',
#              'length': 12,
#              'name': 'zip',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'latitude',
#              'name': 'latitude',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'longitude',
#              'name': 'longitude',
#              'type': 'esriFieldTypeDouble'}],
#  'geometryType': 'esriGeometryPoint',
#  'spatialReference': {'latestWkid': 4326, 'wkid': 4326}}

# %%
name = []
city = []
lat = []
lng = []

features = response["features"]

for feature in features:
    name.append(feature['attributes']['Name'])
    city.append(feature['attributes']['city'])
    lat.append(feature['attributes']['latitude'])
    lng.append(feature['attributes']['longitude'])
    
# print(f"""
# name :{name}
# city :{city}
# lat :{lat}
# lng :{lng}
# """)

stationsdf = pd.DataFrame({
    "Name": name,
    "Department": city,
    "Lat": lat,
    "Lng": lng
})

stationsdf = stationsdf.sort_values(by="Department", inplace=False)
stationsdf = stationsdf[~stationsdf['Name'].str.contains('Fire')]
stationsdf = stationsdf.reset_index()
stationsdf = stationsdf.drop([7,10,20,32,43,75,78,86])
stationsdf = stationsdf.reset_index()
stationsdf = stationsdf.drop(columns=['level_0', 'index'])
#stationsdf = stationsdf.drop([95])
pd.set_option('display.max_rows', 200)
stationsdf
#starting code for importing officer counts
path = "officers.csv"
officersdf = pd.read_csv(path)
officersdf

finaldf = pd.merge(stationsdf, officersdf, how = 'outer', on='Department')
finaldf = finaldf.fillna(50)
finaldf["Officers"][11] = 394.0
finaldf
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                  Name            Department  \
# 0                          Alhambra Police Department              Alhambra
# 1                            Altadena Sheriff Station              Altadena
# 2                           Arcadia Police Department               Arcadia
# 3                              Avalon Sheriff Station                Avalon
# 4                     City Of Azusa Police Department                 Azusa
# 5              City Of Baldwin Park Police Department          Baldwin Park
# 6                      City Of Bell Police Department                  Bell
# 7              City Of Bell Gardens Police Department          Bell Gardens
# 8             City Of Beverly Hills Police Department         Beverly Hills
# 9                   City Of Burbank Police Department               Burbank
# 10                  Malibu/Lost Hills Sheriff Station             Calabasas
# 11  Los Angeles Police Department - Topanga Commun...           Canoga Park
# 12                             Carson Sheriff Station                Carson
# 13                           Cerritos Sheriff Station              Cerritos
# 14                City Of Claremont Police Department             Claremont
# 15                            Compton Sheriff Station               Compton
# 16                   City Of Covina Police Department                Covina
# 17              City Of Culver City Police Department           Culver City
# 18                   City Of Downey Police Department                Downey
# 19                 City Of El Monte Police Department              El Monte
# 20               City Of El Segundo Police Department            El Segundo
# 21                  City Of Gardena Police Department               Gardena
# 22                 City Of Glendale Police Department              Glendale
# 23                         Glendora Police Department              Glendora
# 24                City Of Hawthorne Police Department             Hawthorne
# 25            City Of Hermosa Beach Police Department         Hermosa Beach
# 26          City Of Huntington Park Police Department       Huntington Park
# 27                           Industry Sheriff Station              Industry
# 28                        Inglewood Police Department             Inglewood
# 29                City Of Irwindale Police Department             Irwindale
# 30                   Crescenta Valley Sheriff Station          La Crescenta
# 31                 City Of La Verne Police Department              La Verne
# 32                           Lakewood Sheriff Station              Lakewood
# 33                          Lancaster Sheriff Station             Lancaster
# 34                    Lawndale Sheriff Service Center              Lawndale
# 35                             Lomita Sheriff Station                Lomita
# 36  Long Beach Police Department - North Patrol Di...            Long Beach
# 37  Long Beach Police Department - South Patrol Di...            Long Beach
# 38               City Of Long Beach Police Department            Long Beach
# 39  Long Beach Police Department - West Patrol Div...            Long Beach
# 40                  South Los Angeles Sheriff Station           Los Angeles
# 41  Los Angeles Police Department - Pacific Commun...           Los Angeles
# 42  Los Angeles Police Department - Hollywood Comm...           Los Angeles
# 43  Los Angeles Police Department - Central Commun...           Los Angeles
# 44  Los Angeles Police Department - Northeast Comm...           Los Angeles
# 45  City Of Los Angeles Police Department - Headqu...           Los Angeles
# 46  Los Angeles Police Department - Southeast Comm...           Los Angeles
# 47                   East Los Angeles Sheriff Station           Los Angeles
# 48  Los Angeles Police Department - Wilshire Commu...           Los Angeles
# 49  Los Angeles County Sheriff - Metro Transit Ser...           Los Angeles
# 50  Los Angeles Police Department - West Los Angel...           Los Angeles
# 51  Los Angeles Police Department - Rampart Commun...           Los Angeles
# 52  Los Angeles Police Department - Newton Communi...           Los Angeles
# 53  Los Angeles Police Department - Southwest Comm...           Los Angeles
# 54  Los Angeles Police Department - Olympic Commun...           Los Angeles
# 55  Los Angeles Police Department - Hollenbeck Com...           Los Angeles
# 56  Los Angeles Police Department - 77Th St. Commu...           Los Angeles
# 57                            Century Sheriff Station               Lynwood
# 58                  Manhattan Beach Police Department       Manhattan Beach
# 59                     Marina Del Rey Sheriff Station        Marina Del Rey
# 60  Los Angeles Police Department - Mission Commun...         Mission Hills
# 61                 City Of Monrovia Police Department              Monrovia
# 62               City Of Montebello Police Department            Montebello
# 63            City Of Monterey Park Police Department         Monterey Park
# 64  Los Angeles Police Department - North Hollywoo...       North Hollywood
# 65  Los Angeles Police Department - Devonshire Com...            Northridge
# 66                            Norwalk Sheriff Station               Norwalk
# 67  Los Angeles Police Department - Foothill Commu...               Pacoima
# 68                           Palmdale Sheriff Station              Palmdale
# 69     City Of Palos Verdes Estates Police Department  Palos Verdes Estates
# 70                        Pico Rivera Sheriff Station           Pico Rivera
# 71                   City Of Pomona Police Department                Pomona
# 72            City Of Redondo Beach Police Department         Redondo Beach
# 73  Los Angeles Police Department - West Valley Co...                Reseda
# 74     Los Angeles County Sheriff - San Dimas Station             San Dimas
# 75                          San Dimas Sheriff Station            San Dimas
# 76             City Of San Fernando Police Department          San Fernando
# 77              City Of San Gabriel Police Department           San Gabriel
# 78               City Of San Marino Police Department            San Marino
# 79             City Of Santa Monica Police Department          Santa Monica
# 80             City Of Sierra Madre Police Department          Sierra Madre
# 81              City Of Signal Hill Police Department           Signal Hill
# 82               City Of South Gate Police Department            South Gate
# 83           City Of South Pasadena Police Department        South Pasadena
# 84                             Temple Sheriff Station           Temple City
# 85                 City Of Torrance Police Department              Torrance
# 86                      Universal Citywalk Substation        Universal City
# 87               Santa Clarita Valley Sheriff Station              Valencia
# 88  Los Angeles Police Department - Van Nuys Commu...              Van Nuys
# 89                   City Of Vernon Police Department                Vernon
# 90                 Walnut/Diamond Bar Sheriff Station                Walnut
# 91              City Of West Covina Police Department           West Covina
# 92                     West Hollywood Sheriff Station        West Hollywood
# 93                 City Of Whittier Police Department              Whittier
# 94  Los Angeles Police Department - Harbor Communi...            Wilmington
# 95                                                 50              Pasadena
#
#           Lat         Lng  Officers
# 0   34.091934 -118.126629      84.0
# 1   34.189574 -118.132478      50.0
# 2   34.136637 -118.039894      66.0
# 3   33.343106 -118.327061      50.0
# 4   34.134137 -117.906387      57.0
# 5   34.085231 -117.960124      65.0
# 6   33.979520 -118.188793      33.0
# 7   33.967195 -118.150414      50.0
# 8   34.072660 -118.400312     117.0
# 9   34.182852 -118.308467     154.0
# 10  34.137357 -118.714185      50.0
# 11  34.221043 -118.598916     394.0
# 12  33.834495 -118.263010      50.0
# 13  33.866331 -118.065922      50.0
# 14  34.096390 -117.722475      37.0
# 15  33.894082 -118.224443      50.0
# 16  34.089779 -117.889006      59.0
# 17  34.020669 -118.395097     100.0
# 18  33.940915 -118.127655     106.0
# 19  34.070934 -118.030504     108.0
# 20  33.919926 -118.415783      56.0
# 21  33.883727 -118.307637      95.0
# 22  34.146927 -118.248869     232.0
# 23  34.135058 -117.865451      51.0
# 24  33.919034 -118.352743      88.0
# 25  33.864350 -118.396028      34.0
# 26  33.979963 -118.218923      51.0
# 27  34.024970 -117.958773      50.0
# 28  33.961476 -118.354325     175.0
# 29  34.104195 -117.934013      28.0
# 30  34.221033 -118.230346      50.0
# 31  34.100824 -117.770837      40.0
# 32  33.851406 -118.133177      50.0
# 33  34.699030 -118.137744      50.0
# 34  33.891502 -118.344184      50.0
# 35  33.785443 -118.320554      50.0
# 36  33.844639 -118.185705     202.0
# 37  33.768986 -118.197253     202.0
# 38  33.768986 -118.197253     202.0
# 39  33.790485 -118.215631     202.0
# 40  33.930899 -118.297854     394.0
# 41  33.991528 -118.420218     394.0
# 42  34.095630 -118.330838     394.0
# 43  34.043827 -118.247307     394.0
# 44  34.118597 -118.249327     394.0
# 45  34.052341 -118.244030     394.0
# 46  33.938438 -118.275445     394.0
# 47  34.034115 -118.157723     394.0
# 48  34.046571 -118.342690     394.0
# 49  34.054971 -118.233460     394.0
# 50  34.043846 -118.450697     394.0
# 51  34.056479 -118.267458     394.0
# 52  34.012564 -118.256302     394.0
# 53  34.010671 -118.305030     394.0
# 54  34.049817 -118.291439     394.0
# 55  34.044758 -118.213091     394.0
# 56  33.970613 -118.278035     394.0
# 57  33.927702 -118.227375      50.0
# 58  33.886956 -118.409282      66.0
# 59  33.969541 -118.445728      50.0
# 60  34.272597 -118.467729     394.0
# 61  34.147949 -118.000061      51.0
# 62  34.020269 -118.116431      66.0
# 63  34.059666 -118.125935      69.0
# 64  34.171986 -118.385863     394.0
# 65  34.256426 -118.531831     394.0
# 66  33.914224 -118.069382      50.0
# 67  34.252971 -118.410835     394.0
# 68  34.586245 -118.117007      50.0
# 69  33.799756 -118.391591      29.0
# 70  33.981915 -118.088892      50.0
# 71  34.054871 -117.754267     154.0
# 72  33.845308 -118.388431      92.0
# 73  34.193695 -118.547432     394.0
# 74  34.104772 -117.801681      50.0
# 75  34.104772 -117.801680      50.0
# 76  34.282780 -118.438624      27.0
# 77  34.094861 -118.099737      49.0
# 78  34.121223 -118.105728      25.0
# 79  34.012945 -118.490387     204.0
# 80  34.161588 -118.058441      15.0
# 81  33.806860 -118.172450      34.0
# 82  33.955691 -118.205232      79.0
# 83  34.115955 -118.152391      35.0
# 84  34.102832 -118.076034      50.0
# 85  33.839990 -118.342418     208.0
# 86  34.135643 -118.351131      50.0
# 87  34.415743 -118.551342      50.0
# 88  34.183573 -118.446386     394.0
# 89  34.004939 -118.231440      39.0
# 90  34.028856 -117.834312      50.0
# 91  34.072023 -117.938079      93.0
# 92  34.083757 -118.383608      50.0
# 93  33.975395 -118.034924     120.0
# 94  33.771490 -118.269774     394.0
# 95  50.000000   50.000000     234.0

# %%
gkey = "AIzaSyCDLQKE0rClBHNWfZ9cYJwrYIaHr4H8zzE"
gmaps.configure(api_key=gkey)

locations = finaldf[["Lat", "Lng"]].astype(float)
numbers = finaldf["Officers"]

la_coord = (34.010671, -118.256302)
fig2 = gmaps.figure(center = la_coord, zoom_level = 10)
station_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=3,
)


fig = gmaps.figure()
fig.add_layer(station_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = finaldf[["Lat", "Lng"]].astype(float)
numbers = finaldf["Officers"]

la_coord = (34.010671, -118.256302)
fig2 = gmaps.figure(center = la_coord, zoom_level = 10)
figure_layout = {
'width': '1200px',
'height': '800px',
'border': '1px solid black',
'padding': '1px'
}
fig2 = gmaps.figure(layout=figure_layout)
heat_layer = gmaps.heatmap_layer(locations, 
                                 weights=numbers)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = True
heat_layer.max_intensity = 300
heat_layer.point_radius = 50
heat_layer.opacity = 0.6

fig2.add_layer(heat_layer)

fig2
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', padding='1px', width='1200px'))

# %%
fig3 = gmaps.figure()
figure_layout = {
'width': '1200px',
'height': '800px',
'border': '1px solid black',
'padding': '1px'
}
fig3 = gmaps.figure(center = la_coord, zoom_level = 10)
fig3.add_layer(heat_layer)
fig3.add_layer(station_layer)

fig3
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
lapd = finaldf.loc[[11,40,42,43,44,45,47,48,49,50,51,53,54,55,56,60,64,65,67,73,88,94]]
lapd

locations2 = lapd[["Lat", "Lng"]].astype(float)
numbers2 = lapd["Officers"]

finaldf.dtypes
station_layer2 = gmaps.symbol_layer(
    locations2, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=3,
)


fig4 = gmaps.figure()
fig4.add_layer(station_layer2)

fig4
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
la_coord = (34.010671, -118.256302)
fig5 = gmaps.figure(center = la_coord, zoom_level = 10)
figure_layout = {
'width': '1200px',
'height': '800px',
'border': '1px solid black',
'padding': '1px'
}
fig5 = gmaps.figure(layout=figure_layout)
heat_layer2 = gmaps.heatmap_layer(locations2, 
                                 weights=numbers2)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer2.dissipating = True
heat_layer2.max_intensity = 300
heat_layer2.point_radius = 50
heat_layer2.opacity = 0.6

fig5.add_layer(heat_layer2)

fig5
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', padding='1px', width='1200px'))

# %%
fig6 = gmaps.figure()
figure_layout = {
'width': '1200px',
'height': '800px',
'border': '1px solid black',
'padding': '1px'
}
fig6 = gmaps.figure(layout=figure_layout)
fig6.add_layer(heat_layer2)
fig6.add_layer(station_layer2)

fig6
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', padding='1px', width='1200px'))

# %%
lapd
# Out:
#                                                  Name       Department  \
# 11  Los Angeles Police Department - Topanga Commun...      Canoga Park
# 40                  South Los Angeles Sheriff Station      Los Angeles
# 42  Los Angeles Police Department - Hollywood Comm...      Los Angeles
# 43  Los Angeles Police Department - Central Commun...      Los Angeles
# 44  Los Angeles Police Department - Northeast Comm...      Los Angeles
# 45  City Of Los Angeles Police Department - Headqu...      Los Angeles
# 47                   East Los Angeles Sheriff Station      Los Angeles
# 48  Los Angeles Police Department - Wilshire Commu...      Los Angeles
# 49  Los Angeles County Sheriff - Metro Transit Ser...      Los Angeles
# 50  Los Angeles Police Department - West Los Angel...      Los Angeles
# 51  Los Angeles Police Department - Rampart Commun...      Los Angeles
# 53  Los Angeles Police Department - Southwest Comm...      Los Angeles
# 54  Los Angeles Police Department - Olympic Commun...      Los Angeles
# 55  Los Angeles Police Department - Hollenbeck Com...      Los Angeles
# 56  Los Angeles Police Department - 77Th St. Commu...      Los Angeles
# 60  Los Angeles Police Department - Mission Commun...    Mission Hills
# 64  Los Angeles Police Department - North Hollywoo...  North Hollywood
# 65  Los Angeles Police Department - Devonshire Com...       Northridge
# 67  Los Angeles Police Department - Foothill Commu...          Pacoima
# 73  Los Angeles Police Department - West Valley Co...           Reseda
# 88  Los Angeles Police Department - Van Nuys Commu...         Van Nuys
# 94  Los Angeles Police Department - Harbor Communi...       Wilmington
#
#           Lat         Lng  Officers
# 11  34.221043 -118.598916     394.0
# 40  33.930899 -118.297854     394.0
# 42  34.095630 -118.330838     394.0
# 43  34.043827 -118.247307     394.0
# 44  34.118597 -118.249327     394.0
# 45  34.052341 -118.244030     394.0
# 47  34.034115 -118.157723     394.0
# 48  34.046571 -118.342690     394.0
# 49  34.054971 -118.233460     394.0
# 50  34.043846 -118.450697     394.0
# 51  34.056479 -118.267458     394.0
# 53  34.010671 -118.305030     394.0
# 54  34.049817 -118.291439     394.0
# 55  34.044758 -118.213091     394.0
# 56  33.970613 -118.278035     394.0
# 60  34.272597 -118.467729     394.0
# 64  34.171986 -118.385863     394.0
# 65  34.256426 -118.531831     394.0
# 67  34.252971 -118.410835     394.0
# 73  34.193695 -118.547432     394.0
# 88  34.183573 -118.446386     394.0
# 94  33.771490 -118.269774     394.0
